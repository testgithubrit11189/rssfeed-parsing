# %%
# !pip install feedparser pandas
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 1.6 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=4d456909592414c0936db85efe07f9dbc0c6cc4b027c24bf20ad429249e3e69c
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.11 sgmllib3k-1.0.0

# %%
import feedparser
import pandas as pd

# %%
from langdetect import detect, DetectorFactory
DetectorFactory.seed = 0  # ensures consistent results

def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"

# %%
#rss feeds
rss_feeds=[
    {"url": "http://feeds.bbci.co.uk/news/rss.xml", "country": "UK", "source": "BBC"},
    {"url": "http://rss.cnn.com/rss/edition.rss", "country": "USA", "source": "CNN"},
    {"url": "https://timesofindia.indiatimes.com/rssfeedstopstories.cms", "country": "India", "source": "Times of India"},
    {"url": "https://www3.nhk.or.jp/rss/news/cat0.xml", "country": "Japan", "source": "NHK"},
    {"url": "https://www.channelnewsasia.com/rssfeeds/8395986", "country": "Singapore", "source": "Channel News Asia"},
    {"url": "https://www.thestar.com.my/rss/news", "country": "Malaysia", "source": "The Star"},
    {"url": "http://www.koreaherald.com/rss/01.xml", "country": "South Korea", "source": "Korea Herald"},
    {"url": "https://www.antaranews.com/rss/nasional.xml", "country": "Indonesia", "source": "Antara News"},
    {"url": "https://www.abc.net.au/news/feed/51120/rss.xml", "country": "Australia", "source": "ABC News"},
    {"url": "https://www.cbc.ca/cmlink/rss-topstories", "country": "Canada", "source": "CBC"},
    {"url": "https://www.france24.com/en/rss", "country": "France", "source": "France24"},
    {"url": "https://rss.dw.com/rdf/rss-en-all", "country": "Germany", "source": "DW News"},
    {"url": "https://feeds.folha.uol.com.br/emcimadahora/rss091.xml", "country": "Brazil", "source": "Folha de S.Paulo"},
    {"url": "https://www.rt.com/rss/news/", "country": "Russia", "source": "RT News"},
    {"url": "https://www.news24.com/rss", "country": "South Africa", "source": "News24"},
    {"url": "https://www.eluniversal.com.mx/rss", "country": "Mexico", "source": "El Universal"},
    {"url": "https://www.arabnews.com/rss.xml", "country": "Saudi Arabia", "source": "Arab News"},
    {"url": "https://www.dailysabah.com/rss/turkey", "country": "Turkey", "source": "Daily Sabah"},
    {"url": "https://www.ansa.it/sito/ansait_rss.xml", "country": "Italy", "source": "ANSA"},
    {"url": "https://www.egyptindependent.com/feed/", "country": "Egypt", "source": "Egypt Independent"},
    {"url": "https://www.jpost.com/Rss/RssFeedsHeadlines.aspx", "country": "Israel", "source": "The Jerusalem Post"},
    {"url": "https://www.nzherald.co.nz/rss", "country": "New Zealand", "source": "NZ Herald"},
    {"url": "https://www.bangkokpost.com/rss/data/rss1.xml", "country": "Thailand", "source": "Bangkok Post"}
]

# %%
import requests

# %%
all_articles=[]

for feed in rss_feeds:
  try:
    response = requests.get(feed["url"], timeout=5)  # Timeout after 5 seconds
    parsed = feedparser.parse(response.content)

    for entry in parsed.entries:
      all_articles.append({
        "title":entry.get("title",""),
        "link":entry.get("link",""),
        "published":entry.get("published",""),
        "country":feed["country"],
        "source":feed["source"],
        "summary":entry.get("summary","")
    })

  except Exception as e:
    print(f"⚠️ Skipping {feed['source']} ({feed['country']}): {e}")
    continue

  print(f"Total articles: {len(all_articles)}")
# Out:
# Total articles: 34
# Total articles: 84
# Total articles: 128
# Total articles: 135
# Total articles: 155
# Total articles: 165
# Total articles: 165
# Total articles: 165
# Total articles: 165
# ⚠️ Skipping CBC (Canada): HTTPSConnectionPool(host='www.cbc.ca', port=443): Read timed out. (read timeout=5)
# Total articles: 165
# Total articles: 318
# Total articles: 418
# Total articles: 518
# Total articles: 518
# Total articles: 518
# Total articles: 518
# Total articles: 568
# Total articles: 596
# Total articles: 606
# Total articles: 636
# Total articles: 636
# Total articles: 636

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=7a5ac51f674409d91a9ab84c7d1305690c4ca2393b12b6ea64e1e31fe400b3f9
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
#conversion to csv
df['Combined_Text'] = df['title'].fillna('') + " " + df['summary'].fillna('')
df['Language'] = df['Combined_Text'].apply(detect_language)
df.drop_duplicates(subset=["title", "link"], inplace=True)
df.to_csv("news_articles.csv",index=False,encoding="utf-8")

print("csv created successfully")
# Out:
# csv created successfully

# %%
grouped = df.groupby('Language')
for lang, group in grouped:
    print(f"\nLanguage: {lang}")
    print(group[['title', 'country', 'link']].head(5))  # Display top 5 headlines
# Out:
# Language: en
#                                                title country  \
# 0  UK net migration in 2024 almost halves to 431,...      UK
# 1  Violent criminals could be released early and ...      UK
# 2  90 lorry loads of humanitarian aid now in Gaza...      UK
# 3  Women with dense breasts should have extra NHS...      UK
# 4  Nike to raise prices as firms face tariffs unc...      UK
#
#                                              link
# 0  https://www.bbc.com/news/articles/ckgx3ekkw1eo
# 1  https://www.bbc.com/news/articles/cql22xwg62vo
# 2  https://www.bbc.com/news/articles/czdyv3jp5elo
# 3  https://www.bbc.com/news/articles/cn0gg7p015jo
# 4  https://www.bbc.com/news/articles/c3315er3gygo
#
# Language: it
#                                                  title country  \
# 568  Disabilità, a Firenze la Casa del 'Durante e d...   Italy
# 569  Google aggiorna Chrome, cambierà da solo le pa...   Italy
# 570      "Quelli della notte" fa 40 anni a La Sapienza   Italy
# 571         In Giappone, nel mondo delle arti marziali   Italy
# 572  Tra tazze e bevande il tè in Italia vale oltre...   Italy
#
#                                                   link
# 568  https://www.ansa.it/responsabilmente/notizie/c...
# 569  https://www.ansa.it/canale_tecnologia/notizie/...
# 570  https://www.ansa.it/sito/notizie/cultura/2025/...
# 571  https://www.ansa.it/canale_viaggi/notizie/mond...
# 572  https://www.ansa.it/canale_terraegusto/notizie...
#
# Language: ja
#                               title country  \
# 128   小泉農相 高騰コメ対策 “国民が求めるスピード感で結果を”   Japan
# 129  長野 須坂 長野電鉄3人死傷の事故 金属製パイプの小屋が衝突   Japan
# 130  米議会下院 減税法案を僅差で可決 トランプ政権の“重要政策”   Japan
# 131       備蓄米「随意契約」とは? 「競争入札」との違いは?   Japan
# 132  新たなガソリン補助措置22日から まず小売価格5円値下がりへ   Japan
#
#                                                   link
# 128  http://www3.nhk.or.jp/news/html/20250522/k1001...
# 129  http://www3.nhk.or.jp/news/html/20250522/k1001...
# 130  http://www3.nhk.or.jp/news/html/20250522/k1001...
# 131  http://www3.nhk.or.jp/news/html/20250522/k1001...
# 132  http://www3.nhk.or.jp/news/html/20250522/k1001...
#
# Language: pt
#                                                  title country  \
# 318  Gripe aviária: quais os sintomas em humanos e ...  Brazil
# 319  Conflito Israel-Palestina já apareceu em quest...  Brazil
# 320                                  A epopeia do café  Brazil
# 321  Donatinho, Manoel Cardeiro e Trio Mocotó fazem...  Brazil
# 322  Justiça manda Prefeitura de SP trocar nomes de...  Brazil
#
#                                                   link
# 318  https://redir.folha.com.br/redir/online/emcima...
# 319  https://redir.folha.com.br/redir/online/emcima...
# 320  https://redir.folha.com.br/redir/online/emcima...
# 321  https://redir.folha.com.br/redir/online/emcima...
# 322  https://redir.folha.com.br/redir/online/emcima...

# %%
for lang, group in grouped:
    filename = f"news_{lang}.csv"
    group.to_csv(filename, index=False, encoding='utf-8')

# %%
print(df['Language'].value_counts())
# Out:
# Language
# en    501
# pt    100
# it     28
# ja      7
# Name: count, dtype: int64

# %%
from google.colab import files
files.download('news_articles.csv')

# %%
import zipfile
import os

# Zip all language-specific CSVs
with zipfile.ZipFile("news_by_language.zip", "w") as zipf:
    for lang in df['Language'].unique():
        filename = f"news_{lang}.csv"
        if os.path.exists(filename):
            zipf.write(filename)

# Download the zip
files.download("news_by_language.zip")

# %%
# Step 1: Group by country and get total article count
country_group = df.groupby('country')

summary = []

for country, group in country_group:
    news_agencies = group['source'].unique().tolist()
    total_articles = len(group)

    summary.append({
        'Country': country,
        'News Agency': ", ".join(news_agencies),
        'Total articles downloaded': total_articles,
        'Total historical data': 'Since 2021'  # update if you have actual dates
    })

# Step 2: Create summary DataFrame
summary_df = pd.DataFrame(summary)

# Step 3: Save or display
summary_df.to_csv("news_summary.csv", index=False)
summary_df
# Out:
#       Country         News Agency  Total articles downloaded  \
# 0      Brazil    Folha de S.Paulo                        100
# 1       Egypt   Egypt Independent                         10
# 2     Germany             DW News                        153
# 3       India      Times of India                         44
# 4      Israel  The Jerusalem Post                         30
# 5       Italy                ANSA                         28
# 6       Japan                 NHK                          7
# 7    Malaysia            The Star                         10
# 8      Russia             RT News                        100
# 9   Singapore   Channel News Asia                         20
# 10     Turkey         Daily Sabah                         50
# 11         UK                 BBC                         34
# 12        USA                 CNN                         50
#
#    Total historical data
# 0             Since 2021
# 1             Since 2021
# 2             Since 2021
# 3             Since 2021
# 4             Since 2021
# 5             Since 2021
# 6             Since 2021
# 7             Since 2021
# 8             Since 2021
# 9             Since 2021
# 10            Since 2021
# 11            Since 2021
# 12            Since 2021
